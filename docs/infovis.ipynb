# %% [markdown]
# # Datasetbeschrijving
#
# ## Los Angeles
#
# Voor dit onderzoek is gebruikgemaakt van de dataset **"Crime Data from 2020 to 2024"**, beschikbaar gesteld door de Los Angeles Police Department (LAPD). De dataset bevat informatie over geregistreerde misdrijven in de stad Los Angeles tussen 2020 en 2024. Elke rij vertegenwoordigt één geregistreerd misdrijf. De dataset bevat ongeveer **1 miljoen observaties (rijen)** en **28 variabelen (kolommen)**.
#
# ### Variabelen in de dataset
#
# #### 1. Identificatie van het misdrijf
#
# Deze variabelen identificeren een specifiek politieverslag:
#
# - **dr_no**: uniek dossiernummer van het misdrijf.
# - **part_1_2**: classificatie van het misdrijf volgens de FBI-indeling (*Part I* of *Part II*).
#
# #### 2. Tijdsgegevens
#
# Deze variabelen beschrijven wanneer het misdrijf plaatsvond en wanneer het werd gemeld:
#
# - **date_rptd**: datum waarop het misdrijf werd gemeld.
# - **date_occ**: datum waarop het misdrijf plaatsvond.
# - **time_occ**: tijdstip waarop het misdrijf plaatsvond.
#
# #### 3. Locatiegegevens
#
# Deze variabelen beschrijven waar het misdrijf plaatsvond:
#
# - **area**: nummer van het LAPD-politiegebied.
# - **area_name**: naam van het politiegebied.
# - **rpt_dist_no**: rapportagedistrict binnen het politiegebied.
# - **location**: afgerond adres van het incident.
# - **cross_street**: dichtstbijzijnde kruising.
# - **lat**: breedtegraad van de locatie.
# - **lon**: lengtegraad van de locatie.
#
# #### 4. Misdrijfkenmerken
#
# Deze variabelen beschrijven het gepleegde misdrijf:
#
# - **crm_cd**: code van het misdrijf.
# - **crm_cd_desc**: beschrijving van het misdrijf.
# - **crm_cd_1**: primaire misdrijfcode.
# - **crm_cd_2**, **crm_cd_3**, **crm_cd_4**: eventuele aanvullende misdrijfcodes.
# - **mocodes**: modus-operandi-codes die aangeven hoe het misdrijf werd gepleegd.
#
# #### 5. Slachtofferkenmerken
#
# Deze variabelen beschrijven kenmerken van het slachtoffer:
#
# - **vict_age**: leeftijd van het slachtoffer.
# - **vict_sex**: geslacht van het slachtoffer.
# - **vict_descent**: etnische of culturele achtergrond van het slachtoffer.
#
# #### 6. Overige incidentkenmerken
#
# Deze variabelen geven aanvullende informatie over het incident:
#
# - **premis_cd** en **premis_desc**: type locatie waar het misdrijf plaatsvond.
# - **weapon_used_cd** en **weapon_desc**: informatie over een eventueel gebruikt wapen.
# - **status** en **status_desc**: status van de zaak.
#
# ### Geselecteerde variabelen
#
# Niet alle variabelen zijn relevant voor het onderzoek. Daarom is een selectie gemaakt van de variabelen die het beste aansluiten bij het analyseren van verschillen in criminaliteit tussen gebieden en slachtofferprofielen.
#
# | Variabele | Doel |
# |------------|------|
# | `date_occ` | Bepalen wanneer een misdrijf plaatsvond |
# | `crm_cd_desc` | Het type misdrijf analyseren |
# | `part_1_2` | Onderscheid maken tussen ernstigere en minder ernstige misdrijven |
# | `area_name` | Criminaliteit tussen verschillende politiegebieden vergelijken |
# | `vict_age` | Leeftijdsverschillen tussen slachtoffers onderzoeken |
# | `vict_sex` | Verschillen tussen mannelijke en vrouwelijke slachtoffers analyseren |
# | `vict_descent` | Verschillen in slachtofferachtergrond onderzoeken |
# | `lat`, `lon` | Geografische spreiding van misdrijven visualiseren en hotspots identificeren |
#
# Deze variabelen bevatten samen informatie over wanneer een misdrijf plaatsvond, waar het plaatsvond, welk type misdrijf het betrof en wie het slachtoffer was. Hierdoor vormen ze een goede basis voor het beantwoorden van de onderzoeksvraag.
#
# ### Afgeleide variabelen
#
# Naast de oorspronkelijke variabelen zijn twee nieuwe variabelen aangemaakt op basis van `date_occ`:
#
# - **year**: het jaar waarin het misdrijf plaatsvond.
# - **month**: de maand waarin het misdrijf plaatsvond.
#
# Deze afgeleide variabelen maken het mogelijk om trends en patronen in criminaliteit over verschillende jaren en maanden te onderzoeken.
#
# ---
#
# ## New York
#
# Voor dit onderzoek is gebruikgemaakt van de dataset "NYPD Arrests Data (Historic)", beschikbaar gesteld door de New York City Police Department (NYPD). De dataset bevat informatie over arrestaties die zijn verricht door de politie in New York City. Elke rij in de dataset vertegenwoordigt één arrestatie. De dataset bevat ongeveer 6,26 miljoen observaties (rijen) en 19 variabelen (kolommen).
#
# ### Variabelen in de dataset
#
# #### 1. Tijdsgegevens
#
# Deze variabelen beschrijven wanneer de arrestatie plaatsvond:
#
# - **arrest_date**: exacte datum van de arrestatie.
#
# #### 2. Delict- en juridische kenmerken
#
# Deze variabelen beschrijven het delict waarvoor iemand is gearresteerd:
#
# - **pd_cd**: gedetailleerde interne classificatiecode van het delict.
# - **pd_desc**: beschrijving van de PD-code.
# - **ky_cd**: algemene classificatiecode van het delict.
# - **ofns_desc**: beschrijving van het type overtreding of misdrijf.
# - **law_code**: verwijzing naar de relevante wetgeving.
# - **law_cat_cd**: ernstcategorie van het delict (*felony*, *misdemeanor* of *violation*).
#
# #### 3. Locatiegegevens
#
# Deze variabelen beschrijven waar de arrestatie plaatsvond:
#
# - **arrest_boro**: stadsdeel waarin de arrestatie plaatsvond (*Bronx, Brooklyn, Manhattan, Queens* of *Staten Island*).
# - **arrest_precinct**: politiedistrict waarin de arrestatie plaatsvond.
# - **jurisdiction_code**: instantie die verantwoordelijk was voor de arrestatie.
# - **x_coord_cd**: X-coördinaat binnen het New York State Plane Coordinate System.
# - **y_coord_cd**: Y-coördinaat binnen het New York State Plane Coordinate System.
# - **latitude**: breedtegraad.
# - **longitude**: lengtegraad.
# - **lon_lat**: gecombineerd geografisch punt op basis van latitude en longitude.
#
# #### 4. Kenmerken van de verdachte
#
# Deze variabelen beschrijven de persoon die is gearresteerd:
#
# - **age_group**: leeftijdscategorie van de verdachte.
# - **perp_sex**: geslacht van de verdachte.
# - **perp_race**: etnische of raciale achtergrond van de verdachte.
#
# ### Geselecteerde variabelen
#
# Voor deze analyse is een selectie gemaakt van de variabelen die relevant zijn voor het onderzoeken van verschillen tussen de stadsdelen van New York en de kenmerken van arrestaties.
#
# | Variabele | Doel |
# |------------|------|
# | `arrest_date` | Bepalen wanneer een arrestatie plaatsvond |
# | `ofns_desc` | Het type overtreding of misdrijf analyseren |
# | `law_cat_cd` | Onderscheid maken tussen overtredingen, misdrijven en ernstige misdrijven |
# | `arrest_boro` | Arrestaties tussen de verschillende stadsdelen vergelijken |
# | `age_group` | Leeftijdsverschillen tussen verdachten onderzoeken |
# | `perp_sex` | Verschillen tussen mannelijke en vrouwelijke verdachten analyseren |
# | `perp_race` | Verschillen in achtergrond van verdachten onderzoeken |
# | `latitude`, `longitude` | Geografische spreiding van arrestaties in kaart brengen |
#
# Deze variabelen geven gezamenlijk inzicht in wanneer een arrestatie plaatsvond, waar deze plaatsvond, waarvoor iemand werd gearresteerd en welke kenmerken de verdachte had.
#
# ### Afgeleide variabelen
#
# Naast de oorspronkelijke variabelen zijn twee nieuwe variabelen aangemaakt op basis van `arrest_date`:
#
# - **year**: het jaar waarin de arrestatie plaatsvond.
# - **month**: de maand waarin de arrestatie plaatsvond.
#
# Deze afgeleide variabelen maken het mogelijk om arrestaties over de tijd te analyseren en trends tussen verschillende jaren en maanden te onderzoeken. Hierdoor kan bijvoorbeeld worden bekeken of bepaalde typen misdrijven vaker voorkomen in specifieke perioden of hoe arrestatiepatronen zich in de loop der jaren hebben ontwikkeld.

# %%
import plotly.graph_objs as go
import plotly.express as px
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import io
import base64
from plotly.subplots import make_subplots
from dash import Dash, dcc, html, Input, Output
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[60], line 9
#       7 import base64
#       8 from plotly.subplots import make_subplots
# ----> 9 from dash import Dash, dcc, html, Input, Output
#      10 from plotly.offline import init_notebook_mode
#      11 init_notebook_mode(connected=True)
#
# ModuleNotFoundError: No module named 'dash'

# %% [markdown]
# # Inladen van datasets

# %% [markdown]
# ## Dataset Los Angeles

# %%
df_lapd = pd.read_csv('Crime_Data_from_2020_to_2024 (1).csv')
display(df_lapd)
print(df_lapd.columns)
# Out:
#              DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 0        211507896  04/11/2021 12:00:00 AM  11/07/2020 12:00:00 AM       845
# 1        201516622  10/21/2020 12:00:00 AM  10/18/2020 12:00:00 AM      1845
# 2        240913563  12/10/2024 12:00:00 AM  10/30/2020 12:00:00 AM      1240
# 3        210704711  12/24/2020 12:00:00 AM  12/24/2020 12:00:00 AM      1310
# 4        201418201  10/03/2020 12:00:00 AM  09/29/2020 12:00:00 AM      1830
# ...            ...                     ...                     ...       ...
# 1004889  240710284  07/24/2024 12:00:00 AM  07/23/2024 12:00:00 AM      1400
# 1004890  240104953  01/15/2024 12:00:00 AM  01/15/2024 12:00:00 AM       100
# 1004891  240410786  10/14/2024 12:00:00 AM  10/11/2024 12:00:00 AM      2330
# 1004892  240309674  04/24/2024 12:00:00 AM  04/24/2024 12:00:00 AM      1500
# 1004893  240910892  08/13/2024 12:00:00 AM  08/12/2024 12:00:00 AM      2300
#
#          AREA    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0          15  N Hollywood         1502         2     354
# 1          15  N Hollywood         1521         1     230
# 2           9     Van Nuys          933         2     354
# 3           7     Wilshire          782         1     331
# 4          14      Pacific         1454         1     420
# ...       ...          ...          ...       ...     ...
# 1004889     7     Wilshire          788         1     510
# 1004890     1      Central          101         2     745
# 1004891     4   Hollenbeck          421         1     341
# 1004892     3    Southwest          358         1     230
# 1004893     9     Van Nuys          914         1     510
#
#                                                Crm Cd Desc  ... Status  \
# 0                                        THEFT OF IDENTITY  ...     IC
# 1           ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT  ...     IC
# 2                                        THEFT OF IDENTITY  ...     IC
# 3        THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...  ...     IC
# 4          THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)  ...     IC
# ...                                                    ...  ...    ...
# 1004889                                   VEHICLE - STOLEN  ...     IC
# 1004890           VANDALISM - MISDEAMEANOR ($399 OR UNDER)  ...     IC
# 1004891  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...  ...     IC
# 1004892     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT  ...     IC
# 1004893                                   VEHICLE - STOLEN  ...     IC
#
#          Status Desc Crm Cd 1 Crm Cd 2  Crm Cd 3 Crm Cd 4  \
# 0        Invest Cont    354.0      NaN       NaN      NaN
# 1        Invest Cont    230.0      NaN       NaN      NaN
# 2        Invest Cont    354.0      NaN       NaN      NaN
# 3        Invest Cont    331.0      NaN       NaN      NaN
# 4        Invest Cont    420.0      NaN       NaN      NaN
# ...              ...      ...      ...       ...      ...
# 1004889  Invest Cont    510.0      NaN       NaN      NaN
# 1004890  Invest Cont    745.0      NaN       NaN      NaN
# 1004891  Invest Cont    341.0      NaN       NaN      NaN
# 1004892  Invest Cont    230.0      NaN       NaN      NaN
# 1004893  Invest Cont    510.0      NaN       NaN      NaN
#
#                                          LOCATION  \
# 0         7800    BEEMAN                       AV
# 1                 ATOLL                        AV
# 2        14600    SYLVAN                       ST
# 3         6000    COMEY                        AV
# 4                         4700    LA VILLA MARINA
# ...                                           ...
# 1004889   4000 W  23RD                         ST
# 1004890   1300 W  SUNSET                       BL
# 1004891   1700    ALBION                       ST
# 1004892           FLOWER                       ST
# 1004893   6900    VESPER                       AV
#
#                             Cross Street      LAT       LON
# 0                                    NaN  34.2124 -118.4092
# 1                               N  GAULT  34.1993 -118.4203
# 2                                    NaN  34.1847 -118.4509
# 3                                    NaN  34.0339 -118.3747
# 4                                    NaN  33.9813 -118.4350
# ...                                  ...      ...       ...
# 1004889                              NaN  34.0362 -118.3284
# 1004890                              NaN  34.0685 -118.2460
# 1004891                              NaN  34.0675 -118.2240
# 1004892  JEFFERSON                    BL  34.0215 -118.2868
# 1004893                              NaN  34.1961 -118.4510
#
# [1004894 rows x 28 columns]
# Index(['DR_NO', 'Date Rptd', 'DATE OCC', 'TIME OCC', 'AREA', 'AREA NAME',
#        'Rpt Dist No', 'Part 1-2', 'Crm Cd', 'Crm Cd Desc', 'Mocodes',
#        'Vict Age', 'Vict Sex', 'Vict Descent', 'Premis Cd', 'Premis Desc',
#        'Weapon Used Cd', 'Weapon Desc', 'Status', 'Status Desc', 'Crm Cd 1',
#        'Crm Cd 2', 'Crm Cd 3', 'Crm Cd 4', 'LOCATION', 'Cross Street', 'LAT',
#        'LON'],
#       dtype='object')

# %% [markdown]
# ## Dataset New York

# %%
df_nypd = pd.read_csv('NYPD_Arrests_Data_(Historic)_20260613.csv')
display(df_nypd)
print(df_nypd.columns)
# Out:
#          ARREST_KEY ARREST_DATE  PD_CD                         PD_DESC  KY_CD  \
# 0         318178990  12/31/2025  101.0                       ASSAULT 3  344.0
# 1         318203916  12/31/2025  494.0  STOLEN PROPERTY 2,1,POSSESSION  111.0
# 2         318196542  12/31/2025  101.0                       ASSAULT 3  344.0
# 3         318196547  12/31/2025  101.0                       ASSAULT 3  344.0
# 4         318200237  12/31/2025  339.0  LARCENY,PETIT FROM OPEN AREAS,  341.0
# ...             ...         ...    ...                             ...    ...
# 1251526   206906423  01/02/2020  273.0            TAMPERING 1,CRIMINAL  121.0
# 1251527   206904269  01/02/2020  339.0  LARCENY,PETIT FROM OPEN AREAS,  341.0
# 1251528   206904271  01/02/2020  922.0  TRAFFIC,UNCLASSIFIED MISDEMEAN  348.0
# 1251529   206901720  01/02/2020  681.0      CHILD, ENDANGERING WELFARE  233.0
# 1251530   206898851  01/02/2020  209.0     BURGLARS TOOLS,UNCLASSIFIED  231.0
#
#                               OFNS_DESC    LAW_CODE LAW_CAT_CD ARREST_BORO  \
# 0          ASSAULT 3 & RELATED OFFENSES  PL 1200001          M           B
# 1         POSSESSION OF STOLEN PROPERTY  PL 1655000          F           B
# 2          ASSAULT 3 & RELATED OFFENSES  PL 1200001          M           B
# 3          ASSAULT 3 & RELATED OFFENSES  PL 1200001          M           K
# 4                         PETIT LARCENY  PL 1552500          M           M
# ...                                 ...         ...        ...         ...
# 1251526  CRIMINAL MISCHIEF & RELATED OF  PL 1452000          F           M
# 1251527                   PETIT LARCENY  PL 1552500          M           Q
# 1251528        VEHICLE AND TRAFFIC LAWS  VTL1220B01          M           Q
# 1251529                      SEX CRIMES  PL 2601001          M           Q
# 1251530                 BURGLAR'S TOOLS  PL 1403500          M           B
#
#          ARREST_PRECINCT  JURISDICTION_CODE AGE_GROUP PERP_SEX  \
# 0                     47                  0       <18        F
# 1                     40                  0     25-44        M
# 2                     40                  2    (null)   (null)
# 3                     77                  0     45-64        M
# 4                     19                  0     45-64        M
# ...                  ...                ...       ...      ...
# 1251526                1                  1     25-44        M
# 1251527              106                  0     45-64        M
# 1251528              115                  3     45-64        M
# 1251529              102                  0     25-44        M
# 1251530               40                  0     18-24        M
#
#                               PERP_RACE  X_COORD_CD  Y_COORD_CD      Latitude  \
# 0                                 BLACK     1023593      261233     40,883621
# 1                                 BLACK     1006229      234035     40,809029
# 2                                 BLACK     1010515      236824     40,816674
# 3                                 BLACK     1003508      185056     40,674601
# 4                                 BLACK      996772      223148     40,779168
# ...                                 ...         ...         ...           ...
# 1251526                           WHITE      982806      201821  40,720636846
# 1251527                  WHITE HISPANIC     1029794      186424   40,67825863
# 1251528  AMERICAN INDIAN/ALASKAN NATIVE     1018623      214936  40,756567585
# 1251529        ASIAN / PACIFIC ISLANDER     1030954      193887  40,698736773
# 1251530                  BLACK HISPANIC     1006572      231983  40,803395714
#
#              Longitude                                        Lon_Lat
# 0            -73,85772                    POINT (-73.85772 40.883621)
# 1           -73,920603                   POINT (-73.920603 40.809029)
# 2           -73,905109                   POINT (-73.905109 40.816674)
# 3           -73,930573                   POINT (-73.930573 40.674601)
# 4           -73,954785                   POINT (-73.954785 40.779168)
# ...                ...                                            ...
# 1251526  -74,005210778   POINT (-74.00521077799993 40.72063684600005)
# 1251527  -73,835802613   POINT (-73.83580261299994 40.67825863000007)
# 1251528  -73,875931534   POINT (-73.87593153399997 40.75656758500002)
# 1251529  -73,831568765  POINT (-73.83156876499999 40.698736773000064)
# 1251530  -73,919373155   POINT (-73.91937315499997 40.80339571400003)
#
# [1251531 rows x 19 columns]
# Index(['ARREST_KEY', 'ARREST_DATE', 'PD_CD', 'PD_DESC', 'KY_CD', 'OFNS_DESC',
#        'LAW_CODE', 'LAW_CAT_CD', 'ARREST_BORO', 'ARREST_PRECINCT',
#        'JURISDICTION_CODE', 'AGE_GROUP', 'PERP_SEX', 'PERP_RACE', 'X_COORD_CD',
#        'Y_COORD_CD', 'Latitude', 'Longitude', 'Lon_Lat'],
#       dtype='object')

# %% [markdown]
# ## Datasets variabelen vergelijken

# %%
df_nypd.info()
df_lapd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1251531 entries, 0 to 1251530
# Data columns (total 19 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   ARREST_KEY         1251531 non-null  int64
#  1   ARREST_DATE        1251531 non-null  object
#  2   PD_CD              1250908 non-null  float64
#  3   PD_DESC            1251391 non-null  object
#  4   KY_CD              1250749 non-null  float64
#  5   OFNS_DESC          1251391 non-null  object
#  6   LAW_CODE           1251531 non-null  object
#  7   LAW_CAT_CD         1242539 non-null  object
#  8   ARREST_BORO        1251531 non-null  object
#  9   ARREST_PRECINCT    1251531 non-null  int64
#  10  JURISDICTION_CODE  1251531 non-null  int64
#  11  AGE_GROUP          1251531 non-null  object
#  12  PERP_SEX           1251531 non-null  object
#  13  PERP_RACE          1251531 non-null  object
#  14  X_COORD_CD         1251531 non-null  int64
#  15  Y_COORD_CD         1251531 non-null  int64
#  16  Latitude           1251527 non-null  object
#  17  Longitude          1251527 non-null  object
#  18  Lon_Lat            1251527 non-null  object
# dtypes: float64(2), int64(5), object(12)
# memory usage: 181.4+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1004894 entries, 0 to 1004893
# Data columns (total 28 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   DR_NO           1004894 non-null  int64
#  1   Date Rptd       1004894 non-null  object
#  2   DATE OCC        1004894 non-null  object
#  3   TIME OCC        1004894 non-null  int64
#  4   AREA            1004894 non-null  int64
#  5   AREA NAME       1004894 non-null  object
#  6   Rpt Dist No     1004894 non-null  int64
#  7   Part 1-2        1004894 non-null  int64
#  8   Crm Cd          1004894 non-null  int64
#  9   Crm Cd Desc     1004894 non-null  object
#  10  Mocodes         853296 non-null   object
#  11  Vict Age        1004894 non-null  int64
#  12  Vict Sex        860263 non-null   object
#  13  Vict Descent    860251 non-null   object
#  14  Premis Cd       1004878 non-null  float64
#  15  Premis Desc     1004306 non-null  object
#  16  Weapon Used Cd  327216 non-null   float64
#  17  Weapon Desc     327216 non-null   object
#  18  Status          1004893 non-null  object
#  19  Status Desc     1004894 non-null  object
#  20  Crm Cd 1        1004883 non-null  float64
#  21  Crm Cd 2        69154 non-null    float64
#  22  Crm Cd 3        2314 non-null     float64
#  23  Crm Cd 4        64 non-null       float64
#  24  LOCATION        1004894 non-null  object
#  25  Cross Street    154228 non-null   object
#  26  LAT             1004894 non-null  float64
#  27  LON             1004894 non-null  float64
# dtypes: float64(8), int64(7), object(13)
# memory usage: 214.7+ MB

# %%
df_nypd.columns.tolist()
df_lapd.columns.tolist()
# Out:
# ['DR_NO',
#  'Date Rptd',
#  'DATE OCC',
#  'TIME OCC',
#  'AREA',
#  'AREA NAME',
#  'Rpt Dist No',
#  'Part 1-2',
#  'Crm Cd',
#  'Crm Cd Desc',
#  'Mocodes',
#  'Vict Age',
#  'Vict Sex',
#  'Vict Descent',
#  'Premis Cd',
#  'Premis Desc',
#  'Weapon Used Cd',
#  'Weapon Desc',
#  'Status',
#  'Status Desc',
#  'Crm Cd 1',
#  'Crm Cd 2',
#  'Crm Cd 3',
#  'Crm Cd 4',
#  'LOCATION',
#  'Cross Street',
#  'LAT',
#  'LON']

# %%
comparison = pd.DataFrame({
    "NYPD": pd.Series(df_nypd.columns),
    "LAPD": pd.Series(df_lapd.columns)
})

comparison
# Out:
#                  NYPD            LAPD
# 0          ARREST_KEY           DR_NO
# 1         ARREST_DATE       Date Rptd
# 2               PD_CD        DATE OCC
# 3             PD_DESC        TIME OCC
# 4               KY_CD            AREA
# 5           OFNS_DESC       AREA NAME
# 6            LAW_CODE     Rpt Dist No
# 7          LAW_CAT_CD        Part 1-2
# 8         ARREST_BORO          Crm Cd
# 9     ARREST_PRECINCT     Crm Cd Desc
# 10  JURISDICTION_CODE         Mocodes
# 11          AGE_GROUP        Vict Age
# 12           PERP_SEX        Vict Sex
# 13          PERP_RACE    Vict Descent
# 14         X_COORD_CD       Premis Cd
# 15         Y_COORD_CD     Premis Desc
# 16           Latitude  Weapon Used Cd
# 17          Longitude     Weapon Desc
# 18            Lon_Lat          Status
# 19                NaN     Status Desc
# 20                NaN        Crm Cd 1
# 21                NaN        Crm Cd 2
# 22                NaN        Crm Cd 3
# 23                NaN        Crm Cd 4
# 24                NaN        LOCATION
# 25                NaN    Cross Street
# 26                NaN             LAT
# 27                NaN             LON

# %% [markdown]
# # missing values bekijken

# %%
missing_nypd = (
    df_nypd.isna()
    .mean()
    .mul(100)
    .sort_values(ascending=False)
)

missing_lapd = (
    df_lapd.isna()
    .mean()
    .mul(100)
    .sort_values(ascending=False)
)
print(missing_nypd)
print(missing_lapd)
# Out:
# LAW_CAT_CD           0.718480
# KY_CD                0.062483
# PD_CD                0.049779
# PD_DESC              0.011186
# OFNS_DESC            0.011186
# Lon_Lat              0.000320
# Longitude            0.000320
# Latitude             0.000320
# PERP_SEX             0.000000
# Y_COORD_CD           0.000000
# X_COORD_CD           0.000000
# PERP_RACE            0.000000
# ARREST_KEY           0.000000
# AGE_GROUP            0.000000
# JURISDICTION_CODE    0.000000
# ARREST_DATE          0.000000
# ARREST_BORO          0.000000
# LAW_CODE             0.000000
# ARREST_PRECINCT      0.000000
# dtype: float64
# Crm Cd 4          99.993631
# Crm Cd 3          99.769727
# Crm Cd 2          93.118279
# Cross Street      84.652312
# Weapon Used Cd    67.437760
# Weapon Desc       67.437760
# Mocodes           15.085969
# Vict Descent      14.393856
# Vict Sex          14.392662
# Premis Desc        0.058514
# Premis Cd          0.001592
# Crm Cd 1           0.001095
# Status             0.000100
# LAT                0.000000
# LOCATION           0.000000
# Status Desc        0.000000
# DR_NO              0.000000
# Date Rptd          0.000000
# Vict Age           0.000000
# Crm Cd Desc        0.000000
# Crm Cd             0.000000
# Part 1-2           0.000000
# Rpt Dist No        0.000000
# AREA NAME          0.000000
# AREA               0.000000
# TIME OCC           0.000000
# DATE OCC           0.000000
# LON                0.000000
# dtype: float64

# %% [markdown]
# ## vorm van datum netjes gemaakt + kolommen jaar en maand toegevoegd

# %%
df_nypd["arrest_date"] = pd.to_datetime(df_nypd["ARREST_DATE"])

df_lapd["DATE OCC"] = pd.to_datetime(df_lapd["DATE OCC"])
# Out:
# C:\Users\lisah\AppData\Local\Temp\ipykernel_31248\2118804888.py:3: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.

# %%
df_nypd["ARREST_DATE"].head(10)
# Out:
# 0    12/31/2025
# 1    12/31/2025
# 2    12/31/2025
# 3    12/31/2025
# 4    12/31/2025
# 5    12/31/2025
# 6    12/31/2025
# 7    12/31/2025
# 8    12/31/2025
# 9    12/31/2025
# Name: ARREST_DATE, dtype: object

# %%
df_lapd["DATE OCC"].head(10)
# Out:
# 0   2020-11-07
# 1   2020-10-18
# 2   2020-10-30
# 3   2020-12-24
# 4   2020-09-29
# 5   2020-11-11
# 6   2020-04-16
# 7   2020-07-07
# 8   2020-03-02
# 9   2020-09-01
# Name: DATE OCC, dtype: datetime64[ns]

# %%
print(df_nypd["ARREST_DATE"].dropna().iloc[:10].tolist())
print(df_lapd["DATE OCC"].dropna().iloc[:10].tolist())
# Out:
# ['12/31/2025', '12/31/2025', '12/31/2025', '12/31/2025', '12/31/2025', '12/31/2025', '12/31/2025', '12/31/2025', '12/31/2025', '12/31/2025']
# [Timestamp('2020-11-07 00:00:00'), Timestamp('2020-10-18 00:00:00'), Timestamp('2020-10-30 00:00:00'), Timestamp('2020-12-24 00:00:00'), Timestamp('2020-09-29 00:00:00'), Timestamp('2020-11-11 00:00:00'), Timestamp('2020-04-16 00:00:00'), Timestamp('2020-07-07 00:00:00'), Timestamp('2020-03-02 00:00:00'), Timestamp('2020-09-01 00:00:00')]

# %%
df_nypd["ARREST_DATE"] = pd.to_datetime(
    df_nypd["ARREST_DATE"],
    format="%m/%d/%Y"
)

# %%
df_nypd["ARREST_DATE"].dtype
# Out:
# dtype('<M8[ns]')

# %%
df_lapd["DATE OCC"].dtype
# Out:
# dtype('<M8[ns]')

# %%
df_nypd["year"] = df_nypd["ARREST_DATE"].dt.year
df_nypd["month"] = df_nypd["ARREST_DATE"].dt.month

df_lapd["year"] = df_lapd["DATE OCC"].dt.year
df_lapd["month"] = df_lapd["DATE OCC"].dt.month

# %%
df_nypd = df_nypd[
    (df_nypd['ARREST_DATE'].dt.year >= 2020) & 
    (df_nypd['ARREST_DATE'].dt.year <= 2023)
]
print(f"NYPD gefilterd: {len(df_nypd)} rijen")
# Out:
# NYPD gefilterd: 712075 rijen

# %%
df_lapd = df_lapd[
    (df_lapd['DATE OCC'].dt.year >= 2020) & 
    (df_lapd['DATE OCC'].dt.year <= 2023)
]

print(f"LAPD gefilterd: {len(df_lapd)} rijen")
# Out:
# LAPD gefilterd: 877327 rijen

# %%
df_nypd = df_nypd[[
    'ARREST_DATE',
    'OFNS_DESC',
    'LAW_CAT_CD',
    'ARREST_BORO',
    'AGE_GROUP',
    'PERP_SEX',
    'PERP_RACE',
    'Latitude',
    'Longitude',
    'year',
    'month'
]]

df_lapd = df_lapd[[
    'DATE OCC',
    'Crm Cd Desc',
    'Part 1-2',
    'AREA NAME',
    'Vict Age',
    'Vict Sex',
    'Vict Descent',
    'LAT',
    'LON',
    'year',
    'month'
]]

print(df_nypd.shape)
print(df_lapd.shape)
# Out:
# (712075, 11)
# (877327, 11)

# %% [markdown]
# ## Visualisaties

# %%
nypd_per_jaar = df_nypd.groupby('year').size().reset_index(name='count')
nypd_per_jaar['city'] = 'NYC (NYPD)'

lapd_per_jaar = df_lapd.groupby('year').size().reset_index(name='count')
lapd_per_jaar['city'] = 'LA (LAPD)'

df_combined = pd.concat([nypd_per_jaar, lapd_per_jaar])

fig, ax = plt.subplots(figsize=(10, 6))

jaren = [2020, 2021, 2022, 2023]
x = range(len(jaren))
breedte = 0.35

nypd_vals = nypd_per_jaar.set_index('year').reindex(jaren)['count']
lapd_vals = lapd_per_jaar.set_index('year').reindex(jaren)['count']

bars1 = ax.bar([i - breedte/2 for i in x], nypd_vals, breedte, label='NYC (NYPD)', color='#1f77b4')
bars2 = ax.bar([i + breedte/2 for i in x], lapd_vals, breedte, label='LA (LAPD)', color='#ff7f0e')

ax.set_xlabel('Jaar', fontsize=12)
ax.set_ylabel('Aantal misdaden / arrestaties', fontsize=12)
ax.set_title('Misdaden per jaar: NYC vs LA (2020–2024)', fontsize=14, fontweight='bold')
ax.set_xticks(list(x))
ax.set_xticklabels(jaren)
ax.legend()
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda val, _: f'{int(val):,}'))

for bar in bars1:
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 500,
            f'{int(bar.get_height()):,}', ha='center', va='bottom', fontsize=9)
for bar in bars2:
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 500,
            f'{int(bar.get_height()):,}', ha='center', va='bottom', fontsize=9)

plt.tight_layout()
plt.savefig('misdaden_per_jaar_nyc_vs_la.png', dpi=150)
plt.show()

# %%
df_nypd['year_month'] = df_nypd['ARREST_DATE'].dt.to_period('M')
df_lapd['year_month'] = df_lapd['DATE OCC'].dt.to_period('M')

nypd_maand = df_nypd.groupby('year_month').size().reset_index(name='count')
lapd_maand = df_lapd.groupby('year_month').size().reset_index(name='count')

nypd_maand['year_month'] = nypd_maand['year_month'].dt.to_timestamp()
lapd_maand['year_month'] = lapd_maand['year_month'].dt.to_timestamp()

fig, ax = plt.subplots(figsize=(14, 5))

ax.plot(nypd_maand['year_month'], nypd_maand['count'], 
        label='NYC (NYPD)', color='#1f77b4', linewidth=2)
ax.plot(lapd_maand['year_month'], lapd_maand['count'], 
        label='LA (LAPD)', color='#ff7f0e', linewidth=2)

ax.set_xticks(pd.date_range('2020-01-01', '2024-01-01', freq='YS'))
ax.set_xticklabels([str(y) for y in range(2020, 2025)])

ax.set_xlabel('Periode', fontsize=12)
ax.set_ylabel('Aantal misdaden / arrestaties', fontsize=12)
ax.set_title('Misdaden per maand: NYC vs LA (2020–2023)', fontsize=14, fontweight='bold')
ax.legend()
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda val, _: f'{int(val):,}'))

plt.tight_layout()
plt.savefig('misdaden_per_maand_nyc_vs_la.png', dpi=150)
plt.show()

# %%
nypd_types = (df_nypd['OFNS_DESC']
              .value_counts()
              .head(10)
              .reset_index())
nypd_types.columns = ['misdaad', 'count']

lapd_types = (df_lapd['Crm Cd Desc']
              .value_counts()
              .head(10)
              .reset_index())
lapd_types.columns = ['misdaad', 'count']

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 7))

bars1 = ax1.barh(nypd_types['misdaad'][::-1], nypd_types['count'][::-1], 
                  color='#1f77b4')
ax1.set_title('Top 10 misdaden — NYC (NYPD)', fontsize=13, fontweight='bold')
ax1.set_xlabel('Aantal arrestaties')
ax1.xaxis.set_major_formatter(plt.FuncFormatter(lambda val, _: f'{int(val):,}'))
for bar in bars1:
    ax1.text(bar.get_width() + 200, bar.get_y() + bar.get_height()/2,
             f'{int(bar.get_width()):,}', va='center', fontsize=8)

bars2 = ax2.barh(lapd_types['misdaad'][::-1], lapd_types['count'][::-1], 
                  color='#ff7f0e')
ax2.set_title('Top 10 misdaden — LA (LAPD)', fontsize=13, fontweight='bold')
ax2.set_xlabel('Aantal meldingen')
ax2.xaxis.set_major_formatter(plt.FuncFormatter(lambda val, _: f'{int(val):,}'))
for bar in bars2:
    ax2.text(bar.get_width() + 200, bar.get_y() + bar.get_height()/2,
             f'{int(bar.get_width()):,}', va='center', fontsize=8)

plt.tight_layout()
plt.savefig('misdaadtypes_nyc_vs_la.png', dpi=150)
plt.show()

# %%
nyc_borough_coords = {
    'MANHATTAN': {'lat': 40.7831, 'lon': -73.9712},
    'BRONX': {'lat': 40.8448, 'lon': -73.8648},
    'BROOKLYN': {'lat': 40.6782, 'lon': -73.9442},
    'QUEENS': {'lat': 40.7282, 'lon': -73.7949},
    'STATEN ISLAND': {'lat': 40.5795, 'lon': -74.1502}
}

# NYPD gebruikt vaak afkortingen: K, Q, M, B, S
nyc_borough_map = {
    'K': 'BROOKLYN', 'Q': 'QUEENS', 'M': 'MANHATTAN', 
    'B': 'BRONX', 'S': 'STATEN ISLAND'
}
df_nypd['borough_naam'] = df_nypd['ARREST_BORO'].map(nyc_borough_map).fillna(df_nypd['ARREST_BORO'])

nypd_coords = pd.DataFrame([
    {'ARREST_BORO': naam, 'Latitude': info['lat'], 'Longitude': info['lon']}
    for naam, info in nyc_borough_coords.items()
])

# %%
la_area_coords = {
    'Central': {'lat': 34.0445, 'lon': -118.2460},
    'Rampart': {'lat': 34.0586, 'lon': -118.2823},
    'Southwest': {'lat': 34.0141, 'lon': -118.3220},
    'Hollenbeck': {'lat': 34.0392, 'lon': -118.2080},
    'Harbor': {'lat': 33.7570, 'lon': -118.2920},
    'Hollywood': {'lat': 34.0980, 'lon': -118.3267},
    'Wilshire': {'lat': 34.0593, 'lon': -118.3470},
    'West LA': {'lat': 34.0461, 'lon': -118.4500},
    'Van Nuys': {'lat': 34.1870, 'lon': -118.4480},
    'West Valley': {'lat': 34.1900, 'lon': -118.5290},
    'Northeast': {'lat': 34.1062, 'lon': -118.2280},
    '77th Street': {'lat': 33.9700, 'lon': -118.2890},
    'Newton': {'lat': 34.0090, 'lon': -118.2540},
    'Pacific': {'lat': 33.9930, 'lon': -118.4280},
    'N Hollywood': {'lat': 34.1870, 'lon': -118.3790},
    'Foothill': {'lat': 34.2570, 'lon': -118.3700},
    'Devonshire': {'lat': 34.2520, 'lon': -118.5350},
    'Southeast': {'lat': 33.9380, 'lon': -118.2480},
    'Mission': {'lat': 34.2720, 'lon': -118.4490},
    'Olympic': {'lat': 34.0610, 'lon': -118.3050},
    'Topanga': {'lat': 34.1980, 'lon': -118.6050}
}

lapd_coords = pd.DataFrame([
    {'AREA NAME': naam, 'LAT': info['lat'], 'LON': info['lon']}
    for naam, info in la_area_coords.items()
])

# %%
print(df_nypd['ARREST_BORO'].unique())
print(df_lapd['AREA NAME'].unique())
# Out:
# ['M' 'B' 'K' 'Q' 'S']
# ['N Hollywood' 'Van Nuys' 'Wilshire' 'Pacific' 'Hollenbeck' 'Southwest'
#  'Northeast' 'Devonshire' 'Topanga' 'Hollywood' 'Olympic' 'Southeast'
#  'Newton' 'Foothill' 'Mission' 'Rampart' 'Central' 'West LA' '77th Street'
#  'West Valley' 'Harbor']

# %%
# NYC mapping toepassen
nyc_borough_map = {
    'K': 'BROOKLYN', 'Q': 'QUEENS', 'M': 'MANHATTAN', 
    'B': 'BRONX', 'S': 'STATEN ISLAND'
}
df_nypd['borough_naam'] = df_nypd['ARREST_BORO'].map(nyc_borough_map)

# Check of alles gemapt is (geen NaN)
print(df_nypd['borough_naam'].isna().sum())  # moet 0 zijn
# Out:
# 0

# %%
print(set(df_lapd['AREA NAME'].unique()) - set(la_area_coords.keys()))  # moet leeg zijn: set()
# Out:
# set()

# %%
# Pie-data per wijk per categorie
nypd_pie_data = df_nypd.groupby(['borough_naam', 'categorie']).size().reset_index(name='count')
lapd_pie_data = df_lapd.groupby(['AREA NAME', 'categorie']).size().reset_index(name='count')

# %%
# --- Top 5 + overig per stad bepalen ---
def top5_plus_overig(df, col):
    top5 = df[col].value_counts().head(5).index.tolist()
    return df[col].apply(lambda x: x if x in top5 else 'Overig')

df_nypd['categorie'] = top5_plus_overig(df_nypd, 'OFNS_DESC')
df_lapd['categorie'] = top5_plus_overig(df_lapd, 'Crm Cd Desc')

# --- Gemiddelde coördinaten per wijk (voor marker-positie) ---
nypd_coords = df_nypd.groupby('ARREST_BORO')[['Latitude', 'Longitude']].mean().reset_index()
lapd_coords = df_lapd.groupby('AREA NAME')[['LAT', 'LON']].mean().reset_index()


# Vaste kleuren per categorie zodat alle pies dezelfde legenda gebruiken
alle_categorieen = sorted(set(df_nypd['categorie'].unique()) | {'Overig'})
kleuren_nypd = px.colors.qualitative.Set3
categorie_kleuren_nypd = {cat: kleuren_nypd[i % len(kleuren_nypd)] 
                          for i, cat in enumerate(sorted(df_nypd['categorie'].unique()))}
categorie_kleuren_lapd = {cat: kleuren_nypd[i % len(kleuren_nypd)] 
                           for i, cat in enumerate(sorted(df_lapd['categorie'].unique()))}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
#     886     res = extract_result(res)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:2454, in GroupBy.mean.<locals>.<lambda>(x)
#    2451 else:
#    2452     result = self._cython_agg_general(
#    2453         "mean",
# -> 2454         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2455         numeric_only=numeric_only,
#    2456     )
#    2457     return result.__finalize__(self.obj, method="groupby")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:6549, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6541 @doc(make_doc("mean", ndim=1))
#    6542 def mean(
#    6543     self,
#    (...)
#    6547     **kwargs,
#    6548 ):
# -> 6549     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:12420, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12413 def mean(
#   12414     self,
#   12415     axis: Axis | None = 0,
#    (...)
#   12418     **kwargs,
#   12419 ) -> Series | float:
# > 12420     return self._stat_function(
#   12421         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12422     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:12377, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12375 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12377 return self._reduce(
#   12378     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12379 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:6457, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6453     raise TypeError(
#    6454         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6455         "with non-numeric dtypes."
#    6456     )
# -> 6457 return op(delegate, skipna=skipna, **kwds)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File ~\anaconda3\Lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\nanops.py:720, in nanmean(values, axis, skipna, mask)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\nanops.py:1701, in _ensure_numeric(x)
#    1699 if isinstance(x, str):
#    1700     # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1701     raise TypeError(f"Could not convert string '{x}' to numeric")
#    1702 try:
#
# TypeError: Could not convert string '40,80876940,8289140,83486740,8221187147840,80876940,87321240,84078840,8442325641240,87321240,81958640,82500340,8362840,83247740,82023540,8204240,89655240,8494528668640,83995340,8442440,8289768481140,80876940,85579340,8991540,84801740,8470280392140,8189240,84477440,8442325641240,82392440,83486740,83559640,8109488377940,84300440,82425240,8113988191640,82091740,82531740,84652540,8113988191640,84300440,8571284704340,86906740,83419640,84476840,8571284704340,87217940,8513184620340,8672540,80738640,8378421209340,83419640,81348140,8810762941240,81686340,85026640,88732540,8540146410640,81686340,83079240,833240,8870340,87054140,8665896271640,85351940,8513840,86615540,84435340,82203140,84873340,8203240,87539340,8470280392140,8189240,83481640,8535983673840,82739640,83504740,8556697827940,8387216384640,83991640,80876940,8204240,829185758640,8450301828240,8189240,86906740,87394440,81676840,80876940,87217940,8256740,8410726741840,88732540,8623093970140,82081540,8726031762940,81926240,85838740,80595840,8341869049840,88732540,8494528668640,82235540,8302246549240,82081540,82427940,85838740,84518840,88732540,84198140,8494528668640,8934114570940,8252014457140,86666440,8351140,8581392724740,84123440,83056840,82627540,82889740,86906740,86666440,89411140,8934114570940,8855193923940,8041540959340,8804669879140,82190340,82365740,83397840,85579340,8402258533740,83123440,83599740,8773933872340,84585540,8140840,820481541140,82369140,8240855575340,82081540,8426718003240,83599740,8410868560740,82337840,88064240,84244840,82338940,83255140,83225940,8132240,83090340,82382540,83951640,84244840,8426718003240,8162058439240,87313440,86439340,86409640,80551540,83787840,85382840,85579340,88544940,82337840,88732540,87089940,88544940,8322821098640,81116240,82338940,8547723562640,86398540,83386740,85674640,83599740,8278116194140,85742440,85838740,8878023476440,8221347738740,87447840,87906740,89462740,8359688248340,8275140,85742440,8441566000240,81335940,81130440,86023540,8160668394540,87577340,88732540,81901940,82262240,84616940,86274240,810253848340,82341540,81901940,8133030743540,81697240,8222710411340,83090340,8464640,85838740,84414440,83043840,8628153323440,8160668394540,86879240,8232390440240,84335640,8660702216540,8768341480140,88732540,8566878184440,8330029321840,83787840,8222710411340,8674754873840,82337840,8604240,84335640,82337840,8317076259240,82986140,82680440,8402313345740,8278116194140,85579340,82337840,83740740,8259840,82337840,8660702216540,8660702216540,8725024013640,81967740,85579340,8266071381640,81212740,83599740,81770340,8856140,82386840,85236740,80877140,8761664355640,88732540,84597540,8446801554540,83508540,84893640,81770340,8446801554540,82337840,8605215060940,8797120175740,88220540,88732540,84968940,88732540,8321057977640,81140240,8095640451240,84893640,81603540,83406240,8483146672340,83087840,8262761518640,8201889511540,8186775960140,84335640,81967740,817740,8082616720440,83514640,81943640,81030540,8235793446940,8787772007140,86906740,85127640,80903440,818758203640,82607440,8579039068840,829185758640,8899681245140,85357840,8196937644840,8477002720940,8262761518640,844343526140,8321616569840,84256540,83326740,8402313345740,81526140,83406740,83043840,84597540,8613523610640,80519240,8581165213340,8847353028740,8103518634640,80718440,87013240,8162058439240,86600140,84719640,8103518634640,81967740,8321057977640,85357840,8402313345740,84335640,8402313345740,8660702216540,8801341543840,82181240,8519378725640,8255301400740,83135240,8201889511540,8613523610640,88604540,8103518634640,82515940,84335640,8371265397640,8709881050640,8613523610640,8604240,9034810472140,86325140,83599740,86906740,86963140,8581165213340,84518840,8856140,8552840,85091740,86136940,85176340,81843740,8583686868240,8624442232540,82857140,84606940,85873840,85240840,86439340,8411740,8091071042840,82279540,81907340,80788440,8398022452440,85776240,8373062750940,85163440,84414440,83928740,8121259950240,83926540,8263840,8272973511240,8121259950240,84 ...
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[111], line 10
#       7 df_lapd['categorie'] = top5_plus_overig(df_lapd, 'Crm Cd Desc')
#       9 # --- Gemiddelde coördinaten per wijk (voor marker-positie) ---
# ---> 10 nypd_coords = df_nypd.groupby('ARREST_BORO')[['Latitude', 'Longitude']].mean().reset_index()
#      11 lapd_coords = df_lapd.groupby('AREA NAME')[['LAT', 'LON']].mean().reset_index()
#      14 # Vaste kleuren per categorie zodat alle pies dezelfde legenda gebruiken
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:2452, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    2445     return self._numba_agg_general(
#    2446         grouped_mean,
#    2447         executor.float_dtype_mapping,
#    2448         engine_kwargs,
#    2449         min_periods=0,
#    2450     )
#    2451 else:
# -> 2452     result = self._cython_agg_general(
#    2453         "mean",
#    2454         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2455         numeric_only=numeric_only,
#    2456     )
#    2457     return result.__finalize__(self.obj, method="groupby")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1998, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1995     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1996     return result
# -> 1998 new_mgr = data.grouped_reduce(array_func)
#    1999 res = self._wrap_agged_manager(new_mgr)
#    2000 if how in ["idxmin", "idxmax"]:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1469, in BlockManager.grouped_reduce(self, func)
#    1465 if blk.is_object:
#    1466     # split on object-dtype blocks bc some columns may raise
#    1467     #  while others do not.
#    1468     for sb in blk._split():
# -> 1469         applied = sb.apply(func)
#    1470         result_blocks = extend_blocks(applied, result_blocks)
#    1471 else:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:393, in Block.apply(self, func, **kwargs)
#     387 @final
#     388 def apply(self, func, **kwargs) -> list[Block]:
#     389     """
#     390     apply the function to my values; return a block if we are not
#     391     one
#     392     """
# --> 393     result = func(self.values, **kwargs)
#     395     result = maybe_coerce_values(result)
#     396     return self._split_op_result(result)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1995, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1992     return result
#    1994 assert alt is not None
# -> 1995 result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1996 return result
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1946, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1944     msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1945     # preserve the kind of exception that raised
# -> 1946     raise type(err)(msg) from err
#    1948 if ser.dtype == object:
#    1949     res_values = res_values.astype(object, copy=False)
#
# TypeError: agg function failed [how->mean,dtype->object]
