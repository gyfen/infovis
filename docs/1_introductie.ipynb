# %% [markdown]
# # Criminaliteit in de VS
# Criminaliteit,VS,
#
# Dit dataverhaal...
#
# ***
#
# Door Lisa Hölscher, Nina Barnhoorn, Sofia van den Berg, Yifan Chen\
# Information Visualisation Groep 4
