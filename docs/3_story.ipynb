# %% [markdown]
# # Data story

# %% [markdown]
# # Criminaliteit tussen New York en Los Angeles
# New York met 8.5 miljoen inwoners meer dan dubbel het inwoneraantal van Los Angeles van 3.9 miljoen. Echter heeft New York een kleiner oppervlakte dan Los Angeles, wat zorgt voor een hoge bevolkingsdichtheid van 28.441 inwoners per mi<sup>2</sup> vergeleken met 8.210 inwoners per mi<sup>2</sup> voor Los Angeles [1, 2]. Het is dan aannemelijk dat een groter inwoneraantal zorgt voor een hoger volume van criminaliteit, echter is dit ook echt het geval?
# <!-- New York heeft niet meer criminaliteit dan Los Angeles  -->
# <!-- waardoor veel mensen dagelijks dicht op elkaar leven en werken. -->
# <!-- Dit vergroot de kans op criminaliteit, zoals diefstal, zakkenrollerij en andere veelvoorkomende misdrijven. Daarnaast trekt de stad jaarlijks miljoenen toeristen aan, wat extra mogelijkheden biedt voor bepaalde vormen van criminaliteit. Ook spelen sociaaleconomische problemen, zoals armoede en bendecriminaliteit in sommige wijken, een rol. Door de grote omvang, drukte en constante stroom van inwoners en bezoekers is het voor politie en andere instanties een uitdaging om criminaliteit volledig te voorkomen.  -->

# %% [markdown]
# ## Misdaden per jaar
# In onderstaande grafiek kan gezien worden dat tussen 2020 en 2023 elk jaar meer misdaden zijn geregistreerd in Los Angeles dan in New York.

# %%
import plotly.graph_objs as go
import plotly.express as px
import pandas as pd
import numpy as np
from plotly.subplots import make_subplots
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)

df_nypd = pd.read_csv("../data/processed/crime_ny_processed.csv")
df_lapd = pd.read_csv("../data/processed/crime_la_processed.csv")
df_pop = pd.read_csv("../data/processed/population.csv")

nyc_pop = df_pop[df_pop["name"] == "New York city"].iloc[0]
la_pop = df_pop[df_pop["name"] == "Los Angeles city"].iloc[0]
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.6.0.min"</script>

# %%
nypd_per_jaar = df_nypd.groupby('year').size().reset_index(name='count')
nypd_per_jaar['city'] = 'NYC (NYPD)'

lapd_per_jaar = df_lapd.groupby('year').size().reset_index(name='count')
lapd_per_jaar['city'] = 'LA (LAPD)'

df_combined = pd.concat([nypd_per_jaar, lapd_per_jaar])

jaren = [2020, 2021, 2022, 2023]

nypd_vals = nypd_per_jaar.set_index('year').reindex(jaren)['count']
lapd_vals = lapd_per_jaar.set_index('year').reindex(jaren)['count']

fig = go.Figure()

fig.add_trace(go.Bar(
    x=jaren,
    y=nypd_vals,
    name='NYC (NYPD)',
    marker_color='#1f77b4',
    text=[f'{int(v):,}' for v in nypd_vals],
    textposition='outside'
))

fig.add_trace(go.Bar(
    x=jaren,
    y=lapd_vals,
    name='LA (LAPD)',
    marker_color='#ff7f0e',
    text=[f'{int(v):,}' for v in lapd_vals],
    textposition='outside'
))

fig.update_layout(
    barmode='group',
    title=dict(text='Misdaden per jaar: NYC vs LA (2020–2023)', font=dict(size=20, family='Arial Black')),
    xaxis_title='Jaar',
    yaxis_title='Aantal misdaden / arrestaties',
    xaxis=dict(tickmode='array', tickvals=jaren),
    yaxis=dict(tickformat=','),
    legend=dict(title=''),
    template='plotly_white',
    width=900,
    height=600
)

fig.show()
# Out:
# <div style="height:600px; width:900px;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.6.0.min.js" integrity="sha256-QaOVwtVY0T02VaHrr6pnoHLCwayMJp4O5n4YyaE3rJk=" crossorigin="anonymous"></script>                <div id="021fb791-82f7-448b-a161-48ca31f84fdc" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("021fb791-82f7-448b-a161-48ca31f84fdc")) {                    Plotly.newPlot(                        "021fb791-82f7-448b-a161-48ca31f84fdc",                        [{"marker":{"color":"#1f77b4"},"name":"NYC (NYPD)","text":["140,413","155,507","189,774","226,872"],"textposition":"outside","x":[2020,2021,2022,2023],"y":{"dtype":"i4","bdata":"fSQCAHNfAgBO5QIAOHYDAA=="},"type":"bar"},{"marker":{"color":"#ff7f0e"},"name":"LA (LAPD)","text":["199,847","209,876","235,259","232,345"],"textposition":"outside","x":[2020,2021,2022,2023],"y":{"dtype":"i4","bdata":"pwwDANQzAwD7lgMAmYsDAA=="},"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattergeo"}],"scattergl": ...

# %% [markdown]
# Wanneer je deze absolute aantallen normaliseert met het inwoneraantal, worden de verschillen nog groter, met een duidelijk hoger aantal geregistreerde misdrijven voor LA vegeleken met NY. Het blijkt dus dat een hoger inwoneraantal niet per se betekent dat het aantal geregistreerde misdaden hoger is.

# %%
# Crime counts per year
nypd_per_jaar = df_nypd.groupby('year').size().reset_index(name='count')
lapd_per_jaar = df_lapd.groupby('year').size().reset_index(name='count')

jaren = [2020, 2021, 2022, 2023]

# Raw counts aligned to years
nypd_vals = nypd_per_jaar.set_index('year').reindex(jaren)['count'].fillna(0)
lapd_vals = lapd_per_jaar.set_index('year').reindex(jaren)['count'].fillna(0)

# Normalize to crimes per 100k inhabitants
nypd_norm = [
    nypd_vals[year] / nyc_pop[f'popestimate{year}'] * 100_000
    for year in jaren
]

lapd_norm = [
    lapd_vals[year] / la_pop[f'popestimate{year}'] * 100_000
    for year in jaren
]

fig = go.Figure()

fig.add_trace(go.Bar(
    x=jaren,
    y=nypd_norm,
    name='NYC (NYPD)',
    marker_color='#1f77b4',
    text=[f'{v:.1f}' for v in nypd_norm],
    textposition='outside'
))

fig.add_trace(go.Bar(
    x=jaren,
    y=lapd_norm,
    name='LA (LAPD)',
    marker_color='#ff7f0e',
    text=[f'{v:.1f}' for v in lapd_norm],
    textposition='outside'
))

fig.update_layout(
    barmode='group',
    title=dict(
        text='Misdaden per 100.000 inwoners: NYC vs LA (2020–2023)',
        font=dict(size=20, family='Arial Black')
    ),
    xaxis_title='Jaar',
    yaxis_title='Misdaden per 100.000 inwoners',
    xaxis=dict(tickmode='array', tickvals=jaren),
    legend=dict(title=''),
    template='plotly_white',
    width=900,
    height=600
)

fig.show()
# Out:
# <div style="height:600px; width:900px;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.6.0.min.js" integrity="sha256-QaOVwtVY0T02VaHrr6pnoHLCwayMJp4O5n4YyaE3rJk=" crossorigin="anonymous"></script>                <div id="f34a6548-6919-4855-af5c-a66d4739bfa4" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("f34a6548-6919-4855-af5c-a66d4739bfa4")) {                    Plotly.newPlot(                        "f34a6548-6919-4855-af5c-a66d4739bfa4",                        [{"marker":{"color":"#1f77b4"},"name":"NYC (NYPD)","text":["1604.5","1840.8","2269.3","2690.0"],"textposition":"outside","x":[2020,2021,2022,2023],"y":[1604.5021544503443,1840.7643598606905,2269.3005160436296,2690.0221180544936],"type":"bar"},{"marker":{"color":"#ff7f0e"},"name":"LA (LAPD)","text":["5128.9","5477.7","6136.9","6037.6"],"textposition":"outside","x":[2020,2021,2022,2023],"y":[5128.92043650758,5477.677282761379,6136.887661819167,6037.618276589934],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth":0,"tic ...

# %% [markdown]
# ## Misdaden per maand
# We kunnen ook inzoomen op de data, en de maandelijkse trend tussen NY en LA vergelijken. De verwachting is dat de maandelijke trend tussen beiden steden vergelijkbaar is.

# %%
df_nypd['year_month'] = pd.to_datetime(df_nypd['arrest_date']).dt.to_period('M')
df_lapd['year_month'] = pd.to_datetime(df_lapd['date_occ']).dt.to_period('M')

nypd_maand = df_nypd.groupby('year_month').size().reset_index(name='count')
lapd_maand = df_lapd.groupby('year_month').size().reset_index(name='count')

nypd_maand['year_month'] = nypd_maand['year_month'].dt.to_timestamp()
lapd_maand['year_month'] = lapd_maand['year_month'].dt.to_timestamp()

fig = go.Figure()

fig.add_trace(go.Scatter(
    x=nypd_maand['year_month'],
    y=nypd_maand['count'],
    mode='lines',
    name='NYC (NYPD)',
    line=dict(color='#1f77b4', width=2)
))

fig.add_trace(go.Scatter(
    x=lapd_maand['year_month'],
    y=lapd_maand['count'],
    mode='lines',
    name='LA (LAPD)',
    line=dict(color='#ff7f0e', width=2)
))

fig.update_layout(
    title=dict(text='Misdaden per maand: NYC vs LA (2020–2023)', font=dict(size=20, family='Arial Black')),
    xaxis_title='Periode',
    yaxis_title='Aantal misdaden / arrestaties',
    xaxis=dict(
        tickmode='array',
        tickvals=pd.date_range('2020-01-01', '2024-01-01', freq='YS'),
        ticktext=[str(y) for y in range(2020, 2025)]
    ),
    yaxis=dict(tickformat=','),
    legend=dict(title=''),
    template='plotly_white',
    width=900,
    height=500
)

fig.show()
# Out:
# <div style="height:500px; width:900px;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.6.0.min.js" integrity="sha256-QaOVwtVY0T02VaHrr6pnoHLCwayMJp4O5n4YyaE3rJk=" crossorigin="anonymous"></script>                <div id="c0b6de07-3878-415c-ac0c-939c97e9d73e" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("c0b6de07-3878-415c-ac0c-939c97e9d73e")) {                    Plotly.newPlot(                        "c0b6de07-3878-415c-ac0c-939c97e9d73e",                        [{"line":{"color":"#1f77b4","width":2},"mode":"lines","name":"NYC (NYPD)","x":["2020-01-01T00:00:00.000000","2020-02-01T00:00:00.000000","2020-03-01T00:00:00.000000","2020-04-01T00:00:00.000000","2020-05-01T00:00:00.000000","2020-06-01T00:00:00.000000","2020-07-01T00:00:00.000000","2020-08-01T00:00:00.000000","2020-09-01T00:00:00.000000","2020-10-01T00:00:00.000000","2020-11-01T00:00:00.000000","2020-12-01T00:00:00.000000","2021-01-01T00:00:00.000000","2021-02-01T00:00:00.000000","2021-03-01T00:00:00.000000","2021-04-01T00:00:00.000000","2021-05-01T00:00:00.000000","2021-06-01T00:00:00.000000","2021-07-01T00:00:00.000000","2021-08-01T00:00:00.000000","2021-09-01T00:00:00.000000","2021-10-01T00:00:00.000000","2021-11-01T00:00:00.000000","2021-12-01T00:00:00.000000","2022-01-01T00:00:00.000000","2022-02-01T00:00:00.000000","2022-03-01T00:00:00.000000","2022-04-01T00:00:00.000000","2022-05-01T00:00:00.000000","2022-06-01T00:00:00.000000","2022-07-01T00:00:00.000000","2022-08-01T00:00:00.000000","2022-09-01T00:00:00.000000","2022-10-01T00:00:00.000000","2022-11-01T00:00:00.000000","2022-12-01T00:00:00.000000","2023-01-01T00:00:00.000000","2023-02-01T00:00:00.000000","2023-03-01T00:00:00.000000","2023-04-01T00:00:00.000000","2023-05-01T00:00:00.000000","2023-06-01T00:00:00.000000","2023-07-01T00:00:00.000000","2023-08-01T00:00:00.000000","2023-09-01T00:00:00.000000","2023-10-01T00:00:00.000000","2023-11-01T00:00:00.000000","2023-12-01T00:00:00.000000"],"y":{"dtype":"i2","bdata":"Kz9wPHszZyANNZMfJR1kJigs4zLLLAExwjSFLZw2uCguLjIy+TSxNbw1dTgMM5ExhjP2NixCyj6oQBJAsT11PQg+BkMXQdc7gUloQVxKf0fmTiJM1kq1TR1I0E3OSiZF"},"type":"scatter"},{"line":{"color":"#ff7f0e","width":2},"mode":"lines","name":"LA (LAPD)","x":["2020-01-01T00:00:00.000000","2020-02-01T00:00:00.000000","2020-03-01T00:00:00.000000","2020-04-01T00:00:00.000000","2020-05-01T00:00:00.000000","2020-06-01T00:00:00.000000","2020-07-01T00:00:00.000000","2020-08-01T00:00:00.000000","2020-09-01T00:00:00.000000","2020-10-01T00:00:00.000000","2020-11-01T00:00:00.000000","2020-12-01T00:00:00.000000","2021-01-01T00:00:00.000000","2021-02-01T00:00:00.000000","2021-03-01T00:00:00.000000","2021-04-01T00:00:00.000000","2021-05-01T00:00:00.000000","2021-06-01T00:00:00.000000","2021-07-01T00:00:00.000000","2021-08-01T00:00:00.000000","2021-09-01T00:00:00.000000","2021-10-01T00:00:00.000000","2021-11-01T00:00:00.000000","2021-12-01T00:00:00.000000","2022-01-01T00:00:00.000000","2022-02-01T00:00:00.000000","2022-03-01T00:00:00.000000","2022-04-01T00:00:00.000000","2022-05-01T00:00:00.000000","2022-06-01T00:00:00.000000","2022-07-01T00:00:00.000000","2022-08-01T00:00:00.000000","2022-09-01T00:00:00.000000","2022-10-01T00:00:00.000000","2022-11-01T00:00:00.000000","2022-12-01T00:00:00.000000","2023-01-01T00:00:00.000000","2023-02-01T00:00:00.000000","2023-03-01T00:00:00.000000","2023-04-01T00:00:00.000000","2023-05-01T00:00:00.000000","2023-06-01T00:00:00.000000","2023-07-01T00:00:00.000000","2023-08-01T00:00:00.000000","2023-09-01T00:00:00.000000","2023-10-01T00:00:00.000000","2023-11-01T00:00:00.000000","2023-12-01T00:00:00.000000"],"y":{"dtype":"i2","bdata":"kEiEQzw\u002fWj1OQ6RCBkMGQio9fkDsPGs+\u002fEBQPOI\u002f2z58Qh5DAkneR9JHj0vGRypGh0hWRSFNfU3zTzFPKU6wTo1Lb09DSUROAk45SA5L+UncSTVJ301yTnlLmk6CSmBM"},"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"whi ...

# %%
# Monthly counts
df_nypd['year_month'] = pd.to_datetime(df_nypd['arrest_date']).dt.to_period('M')
df_lapd['year_month'] = pd.to_datetime(df_lapd['date_occ']).dt.to_period('M')

nypd_maand = df_nypd.groupby('year_month').size().reset_index(name='count')
lapd_maand = df_lapd.groupby('year_month').size().reset_index(name='count')

nypd_maand['year_month'] = nypd_maand['year_month'].dt.to_timestamp()
lapd_maand['year_month'] = lapd_maand['year_month'].dt.to_timestamp()

# Normalize to crimes per 100k inhabitants
nypd_maand['rate_per_100k'] = nypd_maand.apply(
    lambda row: row['count'] / nyc_pop[f'popestimate{row["year_month"].year}'] * 100_000,
    axis=1
)

lapd_maand['rate_per_100k'] = lapd_maand.apply(
    lambda row: row['count'] / la_pop[f'popestimate{row["year_month"].year}'] * 100_000,
    axis=1
)

fig = go.Figure()

fig.add_trace(go.Scatter(
    x=nypd_maand['year_month'],
    y=nypd_maand['rate_per_100k'],
    mode='lines',
    name='NYC (NYPD)',
    line=dict(color='#1f77b4', width=2)
))

fig.add_trace(go.Scatter(
    x=lapd_maand['year_month'],
    y=lapd_maand['rate_per_100k'],
    mode='lines',
    name='LA (LAPD)',
    line=dict(color='#ff7f0e', width=2)
))

fig.update_layout(
    title=dict(
        text='Misdaden per maand per 100.000 inwoners: NYC vs LA (2020–2023)',
        font=dict(size=20, family='Arial Black')
    ),
    xaxis_title='Periode',
    yaxis_title='Misdaden per 100.000 inwoners',
    xaxis=dict(
        tickmode='array',
        tickvals=pd.date_range('2020-01-01', '2024-01-01', freq='YS'),
        ticktext=[str(y) for y in range(2020, 2025)]
    ),
    legend=dict(title=''),
    template='plotly_white',
    width=900,
    height=500
)

fig.show()
# Out:
# <div style="height:500px; width:900px;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.6.0.min.js" integrity="sha256-QaOVwtVY0T02VaHrr6pnoHLCwayMJp4O5n4YyaE3rJk=" crossorigin="anonymous"></script>                <div id="1fcd6738-ab55-4d91-9bd6-350ec7b68e52" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("1fcd6738-ab55-4d91-9bd6-350ec7b68e52")) {                    Plotly.newPlot(                        "1fcd6738-ab55-4d91-9bd6-350ec7b68e52",                        [{"line":{"color":"#1f77b4","width":2},"mode":"lines","name":"NYC (NYPD)","x":["2020-01-01T00:00:00.000000","2020-02-01T00:00:00.000000","2020-03-01T00:00:00.000000","2020-04-01T00:00:00.000000","2020-05-01T00:00:00.000000","2020-06-01T00:00:00.000000","2020-07-01T00:00:00.000000","2020-08-01T00:00:00.000000","2020-09-01T00:00:00.000000","2020-10-01T00:00:00.000000","2020-11-01T00:00:00.000000","2020-12-01T00:00:00.000000","2021-01-01T00:00:00.000000","2021-02-01T00:00:00.000000","2021-03-01T00:00:00.000000","2021-04-01T00:00:00.000000","2021-05-01T00:00:00.000000","2021-06-01T00:00:00.000000","2021-07-01T00:00:00.000000","2021-08-01T00:00:00.000000","2021-09-01T00:00:00.000000","2021-10-01T00:00:00.000000","2021-11-01T00:00:00.000000","2021-12-01T00:00:00.000000","2022-01-01T00:00:00.000000","2022-02-01T00:00:00.000000","2022-03-01T00:00:00.000000","2022-04-01T00:00:00.000000","2022-05-01T00:00:00.000000","2022-06-01T00:00:00.000000","2022-07-01T00:00:00.000000","2022-08-01T00:00:00.000000","2022-09-01T00:00:00.000000","2022-10-01T00:00:00.000000","2022-11-01T00:00:00.000000","2022-12-01T00:00:00.000000","2023-01-01T00:00:00.000000","2023-02-01T00:00:00.000000","2023-03-01T00:00:00.000000","2023-04-01T00:00:00.000000","2023-05-01T00:00:00.000000","2023-06-01T00:00:00.000000","2023-07-01T00:00:00.000000","2023-08-01T00:00:00.000000","2023-09-01T00:00:00.000000","2023-10-01T00:00:00.000000","2023-11-01T00:00:00.000000","2023-12-01T00:00:00.000000"],"y":{"dtype":"f8","bdata":"9gs5sikZZ0BHXPozkBlmQKS7eiIY02JA0TQXWWCyV0DDLPxpF2ZjQPzkO6VVF1dAkpwzn3JQVUBtLHgPgRNcQHaipht5JWBAeedqZIObYkD6ZeOPE2FgQK8GF01D62FAjNoLPe\u002f7Y0BBqyR\u002fCT5hQKBxdBp7r2RAj7kMSwLZXkAlaPh0DX5hQOUBDs1yA2NAhOQqmcQQZECTdXscd1ZkQMWqgcihWmRA9mB\u002f\u002f6ViZUBI2s5MBlZjQPiCJ5p2xmJA\u002f7jh4zG3Y0ACiC397QdlQPdQ8+YkUmlA\u002fkZwO8QGaEDAIDe7rL1oQDAG0NlGhGhAAIsysj2bZ0D6GdYkSIRnQOMukiWIvGdASZYpApClaUDY8e4zJuhoQB0OpQjd5WZAQPkwop\u002fja0Ap9BTPE9FoQHo8yaq3NmxA+l6nfZkga0AsqKi3m+9tQHcK\u002f9r54mxA+31R1wFlbEBrBFRI4nttQHSB+2+MXGtAJO2s3CCGbUA12s7H+GFsQLQPcdCQPGpA"},"type":"scatter"},{"line":{"color":"#ff7f0e","width":2},"mode":"lines","name":"LA (LAPD)","x":["2020-01-01T00:00:00.000000","2020-02-01T00:00:00.000000","2020-03-01T00:00:00.000000","2020-04-01T00:00:00.000000","2020-05-01T00:00:00.000000","2020-06-01T00:00:00.000000","2020-07-01T00:00:00.000000","2020-08-01T00:00:00.000000","2020-09-01T00:00:00.000000","2020-10-01T00:00:00.000000","2020-11-01T00:00:00.000000","2020-12-01T00:00:00.000000","2021-01-01T00:00:00.000000","2021-02-01T00:00:00.000000","2021-03-01T00:00:00.000000","2021-04-01T00:00:00.000000","2021-05-01T00:00:00.000000","2021-06-01T00:00:00.000000","2021-07-01T00:00:00.000000","2021-08-01T00:00:00.000000","2021-09-01T00:00:00.000000","2021-10-01T00:00:00.000000","2021-11-01T00:00:00.000000","2021-12-01T00:00:00.000000","2022-01-01T00:00:00.000000","2022-02-01T00:00:00.000000","2022-03-01T00:00:00.000000","2022-04-01T00:00:00.000000","2022-05-01T00:00:00.000000","2022-06-01T00:00:00.000000","2022-07-01T00:00:00.000000","2022-08-01T00:00:00.000000","2022-09-01T00:00:00.000000","2022-10-01T00:00:00.000000","2022-11-01T00:00:00.000000","2022-12-01T00:00:00.000000","2023-01-01T00:00:00.000000","2023-02-01T00:00:00.000000","2023-03-01T00:00:00.000000","2023-04-01T00:00:00.000000","2023-05-01T00:00:00.000000","2023-06-01T00:00:00.000000","2023-07-01T00:00:00.000000","2 ...

# %% [markdown]
# De maandelijkse trend lijk inderdaad voor beide steden vergelijkbaar te zijn, met pieken en dalen op vergelijkbare plekken op de x-as.

# %% [markdown]
# ## Misdaden per categorie
# Naast het totale aantal, kan er ook gekeken worden naar de aantallen per categorie.

# %%
nypd_types = (df_nypd['ofns_desc']
              .value_counts()
              .head(10)
              .reset_index())
nypd_types.columns = ['misdaad', 'count']

lapd_types = (df_lapd['crm_cd_desc']
              .value_counts()
              .head(10)
              .reset_index())
lapd_types.columns = ['misdaad', 'count']

fig = make_subplots(
    rows=2, cols=1,
    subplot_titles=(
        'Top 10 misdaden — NYC (NYPD)',
        'Top 10 misdaden — LA (LAPD)'
    ),
    vertical_spacing=0.12
)

fig.add_trace(
    go.Bar(
        x=nypd_types['count'][::-1],
        y=nypd_types['misdaad'][::-1],
        orientation='h',
        marker_color='#1f77b4',
        # text=[f'{int(v):,}' for v in nypd_types['count'][::-1]],
        # textposition='inside',
        name='NYC (NYPD)',
        # width=0.6
    ),
    row=1, col=1
)

fig.add_trace(
    go.Bar(
        x=lapd_types['count'][::-1],
        y=lapd_types['misdaad'][::-1],
        orientation='h',
        marker_color='#ff7f0e',
        # text=[f'{int(v):,}' for v in lapd_types['count'][::-1]],
        # textposition='inside',
        name='LA (LAPD)',
        # width=0.8
    ),
    row=2, col=1
)

fig.update_xaxes(
    title_text='Aantal arrestaties',
    tickformat=',',
    row=1, col=1
)

fig.update_xaxes(
    title_text='Aantal meldingen',
    tickformat=',',
    row=2, col=1
)

fig.update_yaxes(
    tickfont=dict(size=10),
    ticklabelstandoff=10
)

fig.update_layout(
    showlegend=False,
    template='plotly_white',
    width=900,
    height=900,  # increase height for stacked plots
    title=dict(font=dict(size=20, family='Arial Black')),
    # bargap=0.05
)

fig.update_xaxes(matches='x')

fig.show()
# Out:
# <div style="height:900px; width:900px;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.6.0.min.js" integrity="sha256-QaOVwtVY0T02VaHrr6pnoHLCwayMJp4O5n4YyaE3rJk=" crossorigin="anonymous"></script>                <div id="b1de8f0f-0fc4-4e0a-acf3-b287bc3e9b4a" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("b1de8f0f-0fc4-4e0a-acf3-b287bc3e9b4a")) {                    Plotly.newPlot(                        "b1de8f0f-0fc4-4e0a-acf3-b287bc3e9b4a",                        [{"marker":{"color":"#1f77b4"},"name":"NYC (NYPD)","orientation":"h","x":{"dtype":"i4","bdata":"PnMAADt7AACCgAAAyo8AAKeVAAD+tgAA27sAAM4NAQD1DQEAqMEBAA=="},"y":["VEHICLE AND TRAFFIC LAWS","DANGEROUS WEAPONS","GRAND LARCENY","ROBBERY","CRIMINAL MISCHIEF & RELATED OF","MISCELLANEOUS PENAL LAW","DANGEROUS DRUGS","FELONY ASSAULT","PETIT LARCENY","ASSAULT 3 & RELATED OFFENSES"],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#ff7f0e"},"name":"LA (LAPD)","orientation":"h","x":{"dtype":"i4","bdata":"poMAAMWqAABirwAApMIAAJXPAACj0AAA5tIAAJjbAAAtDwEA6m0BAA=="},"y":["THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)","INTIMATE PARTNER - SIMPLE ASSAULT","THEFT PLAIN - PETTY ($950 & UNDER)","ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT","VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS)","BURGLARY","BURGLARY FROM VEHICLE","THEFT OF IDENTITY","BATTERY - SIMPLE ASSAULT","VEHICLE - STOLEN"],"type":"bar","xaxis":"x2","yaxis":"y2"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar": ...

# %% [markdown]
# Uit bovenstaande grafiek kan afgeleid worden de meeste frequente soort misdaad verschilt tussen NY en LA: In NY is de meest voorkomende misdaad mishandeling van de derde graad, terwijl in LA autodiefstal het hoogste volume heeft.

# %% [markdown]
# # Criminaliteit binnen de steden
# <!-- # De verschillen in criminaliteit tussen wijken zijn groot, zowel in New York als in Los Angeles. -->
# Criminaliteit is niet gelijk verdeeld over een stad. Sommige wijken kennen relatief weinig misdrijven, terwijl andere buurten juist vaker met criminaliteit te maken hebben. Factoren zoals inkomen, werkgelegenheid, onderwijsniveau en de beschikbaarheid van voorzieningen kunnen hierbij een belangrijke rol spelen. Zowel in New York als in Los Angeles bestaan grote sociaaleconomische verschillen tussen wijken. Gebieden waarin meer wordt geïnvesteerd in openbare voorzieningen, sociale programma’s en veiligheid laten vaak lagere criminaliteitscijfers zien. Daardoor geeft een gemiddeld criminaliteitscijfer voor een hele stad niet altijd een nauwkeurig beeld van de veiligheid op wijkniveau.

# %% [markdown]
# ## Verdeling van soorten criminaliteit in New York
# In onderstaande grafiek staan de verdelingen van misdaadcategorieën per borough in NY.

# %%
nyc_borough_coords = {
    'MANHATTAN': {'lat': 40.7831, 'lon': -73.9712},
    'BRONX': {'lat': 40.8448, 'lon': -73.8648},
    'BROOKLYN': {'lat': 40.6782, 'lon': -73.9442},
    'QUEENS': {'lat': 40.7282, 'lon': -73.7949},
    'STATEN ISLAND': {'lat': 40.5795, 'lon': -74.1502}
}

# NYPD gebruikt vaak afkortingen: K, Q, M, B, S
nyc_borough_map = {
    'K': 'BROOKLYN', 'Q': 'QUEENS', 'M': 'MANHATTAN',
    'B': 'BRONX', 'S': 'STATEN ISLAND'
}
df_nypd['borough_naam'] = df_nypd['arrest_boro'].map(nyc_borough_map).fillna(df_nypd['arrest_boro'])

nypd_coords = pd.DataFrame([
    {'borough_naam': naam, 'Latitude': info['lat'], 'Longitude': info['lon']}
    for naam, info in nyc_borough_coords.items()
])

la_area_coords = {
    'Central': {'lat': 34.0445, 'lon': -118.2460},
    'Rampart': {'lat': 34.0586, 'lon': -118.2823},
    'Southwest': {'lat': 34.0141, 'lon': -118.3220},
    'Hollenbeck': {'lat': 34.0392, 'lon': -118.2080},
    'Harbor': {'lat': 33.7570, 'lon': -118.2920},
    'Hollywood': {'lat': 34.0980, 'lon': -118.3267},
    'Wilshire': {'lat': 34.0593, 'lon': -118.3470},
    'West LA': {'lat': 34.0461, 'lon': -118.4500},
    'Van Nuys': {'lat': 34.1870, 'lon': -118.4480},
    'West Valley': {'lat': 34.1900, 'lon': -118.5290},
    'Northeast': {'lat': 34.1062, 'lon': -118.2280},
    '77th Street': {'lat': 33.9700, 'lon': -118.2890},
    'Newton': {'lat': 34.0090, 'lon': -118.2540},
    'Pacific': {'lat': 33.9930, 'lon': -118.4280},
    'N Hollywood': {'lat': 34.1870, 'lon': -118.3790},
    'Foothill': {'lat': 34.2570, 'lon': -118.3700},
    'Devonshire': {'lat': 34.2520, 'lon': -118.5350},
    'Southeast': {'lat': 33.9380, 'lon': -118.2480},
    'Mission': {'lat': 34.2720, 'lon': -118.4490},
    'Olympic': {'lat': 34.0610, 'lon': -118.3050},
    'Topanga': {'lat': 34.1980, 'lon': -118.6050}
}

lapd_coords = pd.DataFrame([
    {'area_name': naam, 'LAT': info['lat'], 'LON': info['lon']}
    for naam, info in la_area_coords.items()
])

# %%
# NYC mapping toepassen
nyc_borough_map = {
    'K': 'BROOKLYN', 'Q': 'QUEENS', 'M': 'MANHATTAN',
    'B': 'BRONX', 'S': 'STATEN ISLAND'
}
df_nypd['borough_naam'] = df_nypd['arrest_boro'].map(nyc_borough_map)

# Check of alles gemapt is (geen NaN)
# print(df_nypd['borough_naam'].isna().sum())  # moet 0 zijn

# print(set(df_lapd['area_name'].unique()) - set(la_area_coords.keys()))  # moet leeg zijn: set()

# %%
# --- Top 5 + overig per stad bepalen ---
def top5_plus_overig(df, col):
    top5 = df[col].value_counts().head(5).index.tolist()
    return df[col].apply(lambda x: x if x in top5 else 'Overig')

df_nypd['categorie'] = top5_plus_overig(df_nypd, 'ofns_desc')
df_lapd['categorie'] = top5_plus_overig(df_lapd, 'crm_cd_desc')


# Vaste kleuren per categorie zodat alle pies dezelfde legenda gebruiken
alle_categorieen = sorted(set(df_nypd['categorie'].unique()) | {'Overig'})
kleuren_nypd = px.colors.qualitative.Set3
categorie_kleuren_nypd = {cat: kleuren_nypd[i % len(kleuren_nypd)]
                          for i, cat in enumerate(sorted(df_nypd['categorie'].unique()))}
categorie_kleuren_lapd = {cat: kleuren_nypd[i % len(kleuren_nypd)]
                           for i, cat in enumerate(sorted(df_lapd['categorie'].unique()))}

# %%
# Pie-data per wijk per categorie
nypd_pie_data = df_nypd.groupby(['borough_naam', 'categorie']).size().reset_index(name='count')
lapd_pie_data = df_lapd.groupby(['area_name', 'categorie']).size().reset_index(name='count')

# %%
def maak_donut_grid_kaart(pie_data, coords, wijk_col, kleuren_dict, titel,
                          width=900, cols=3):

    wijken = coords[wijk_col].tolist()
    n_wijken = len(wijken)
    rows = int(np.ceil(n_wijken / cols))

    fig = make_subplots(
        rows=rows,
        cols=cols,
        specs=[[{'type': 'domain'}] * cols for _ in range(rows)],
        subplot_titles=wijken,
        horizontal_spacing=0.05,
        vertical_spacing=0.10
    )

    for i, wijk in enumerate(wijken):
        row = i // cols + 1
        col = i % cols + 1

        wijk_data = pie_data[pie_data[wijk_col] == wijk]

        fig.add_trace(
            go.Pie(
                labels=wijk_data['categorie'],
                values=wijk_data['count'],
                hole=0.4,
                marker=dict(
                    colors=[kleuren_dict.get(c, '#cccccc')
                            for c in wijk_data['categorie']]
                ),
                showlegend=(i == 0),
                textinfo='none'
            ),
            row=row,
            col=col
        )

    fig.update_layout(
        title=titel,
        width=width,
        height=max(500, rows * 350),  # <-- key change
        showlegend=True
    )

    return fig

fig_nyc_c = maak_donut_grid_kaart(
    nypd_pie_data, nypd_coords, 'borough_naam',
    categorie_kleuren_nypd, 'NYC — Misdaadcategorieën per Borough', 900, cols=3
)
fig_nyc_c.show()
# Out:
# <div style="height:700px; width:900px;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.6.0.min.js" integrity="sha256-QaOVwtVY0T02VaHrr6pnoHLCwayMJp4O5n4YyaE3rJk=" crossorigin="anonymous"></script>                <div id="8aa9e634-556d-4cc1-babd-4fff2df5b925" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("8aa9e634-556d-4cc1-babd-4fff2df5b925")) {                    Plotly.newPlot(                        "8aa9e634-556d-4cc1-babd-4fff2df5b925",                        [{"hole":0.4,"labels":["ASSAULT 3 & RELATED OFFENSES","DANGEROUS DRUGS","FELONY ASSAULT","MISCELLANEOUS PENAL LAW","Overig","PETIT LARCENY"],"marker":{"colors":["rgb(141,211,199)","rgb(255,255,179)","rgb(190,186,218)","rgb(251,128,114)","rgb(128,177,211)","rgb(253,180,98)"]},"showlegend":true,"textinfo":"none","values":{"dtype":"i4","bdata":"O1kAAJ46AAAqMwAA6RkAAMpdAQCgYwAA"},"type":"pie","domain":{"x":[0.0,0.3],"y":[0.55,1.0]}},{"hole":0.4,"labels":["ASSAULT 3 & RELATED OFFENSES","DANGEROUS DRUGS","FELONY ASSAULT","MISCELLANEOUS PENAL LAW","Overig","PETIT LARCENY"],"marker":{"colors":["rgb(141,211,199)","rgb(255,255,179)","rgb(190,186,218)","rgb(251,128,114)","rgb(128,177,211)","rgb(253,180,98)"]},"showlegend":false,"textinfo":"none","values":{"dtype":"i4","bdata":"C3wAAD4sAADMRgAA3hoAAGhDAQCZMwAA"},"type":"pie","domain":{"x":[0.35,0.6499999999999999],"y":[0.55,1.0]}},{"hole":0.4,"labels":["ASSAULT 3 & RELATED OFFENSES","DANGEROUS DRUGS","FELONY ASSAULT","MISCELLANEOUS PENAL LAW","Overig","PETIT LARCENY"],"marker":{"colors":["rgb(141,211,199)","rgb(255,255,179)","rgb(190,186,218)","rgb(251,128,114)","rgb(128,177,211)","rgb(253,180,98)"]},"showlegend":false,"textinfo":"none","values":{"dtype":"i4","bdata":"nHMAAOAsAAByTQAAiT8AAF2IAQC4PAAA"},"type":"pie","domain":{"x":[0.7,1.0],"y":[0.55,1.0]}},{"hole":0.4,"labels":["ASSAULT 3 & RELATED OFFENSES","DANGEROUS DRUGS","FELONY ASSAULT","MISCELLANEOUS PENAL LAW","Overig","PETIT LARCENY"],"marker":{"colors":["rgb(141,211,199)","rgb(255,255,179)","rgb(190,186,218)","rgb(251,128,114)","rgb(128,177,211)","rgb(253,180,98)"]},"showlegend":false,"textinfo":"none","values":{"dtype":"i4","bdata":"KmcAALgdAABNPAAA+jQAABsoAQAlLwAA"},"type":"pie","domain":{"x":[0.0,0.3],"y":[0.0,0.45]}},{"hole":0.4,"labels":["ASSAULT 3 & RELATED OFFENSES","DANGEROUS DRUGS","FELONY ASSAULT","MISCELLANEOUS PENAL LAW","Overig","PETIT LARCENY"],"marker":{"colors":["rgb(141,211,199)","rgb(255,255,179)","rgb(190,186,218)","rgb(251,128,114)","rgb(128,177,211)","rgb(253,180,98)"]},"showlegend":false,"textinfo":"none","values":{"dtype":"i2","bdata":"nBFnChkKtA2IPd8K"},"type":"pie","domain":{"x":[0.35,0.6499999999999999],"y":[0.0,0.45]}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.888888888 ...

# %% [markdown]
# Er valt te zien dat de verdelingen verschillen per borough: Manhatten kent veel diefstal (larceny), terwijl bij de andere boroughs mishandeling (assault 3 & related offenses) het meest voorkomt.

# %% [markdown]
# ## Verdeling van soorten criminaliteit in Los Angeles
# In onderstaande grafiek staan de verdelingen van misdaadcategorieën per borough in LA.

# %%
fig_la_c = maak_donut_grid_kaart(
    lapd_pie_data, lapd_coords, 'area_name',
    categorie_kleuren_lapd, 'LA — Misdaadcategorieën per Area', 900, cols=3
)
fig_la_c.show()
# Out:
# <div style="height:2450px; width:900px;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.6.0.min.js" integrity="sha256-QaOVwtVY0T02VaHrr6pnoHLCwayMJp4O5n4YyaE3rJk=" crossorigin="anonymous"></script>                <div id="938be2a7-31ed-4c22-92e3-28577323b83e" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("938be2a7-31ed-4c22-92e3-28577323b83e")) {                    Plotly.newPlot(                        "938be2a7-31ed-4c22-92e3-28577323b83e",                        [{"hole":0.4,"labels":["BATTERY - SIMPLE ASSAULT","BURGLARY","BURGLARY FROM VEHICLE","Overig","THEFT OF IDENTITY","VEHICLE - STOLEN"],"marker":{"colors":["rgb(141,211,199)","rgb(255,255,179)","rgb(190,186,218)","rgb(251,128,114)","rgb(128,177,211)","rgb(253,180,98)"]},"showlegend":true,"textinfo":"none","values":{"dtype":"i4","bdata":"IRkAAPsIAAA0IAAA0Y8AAPgGAAAnDwAA"},"type":"pie","domain":{"x":[0.0,0.3],"y":[0.9428571428571428,1.0]}},{"hole":0.4,"labels":["BATTERY - SIMPLE ASSAULT","BURGLARY","BURGLARY FROM VEHICLE","Overig","THEFT OF IDENTITY","VEHICLE - STOLEN"],"marker":{"colors":["rgb(141,211,199)","rgb(255,255,179)","rgb(190,186,218)","rgb(251,128,114)","rgb(128,177,211)","rgb(253,180,98)"]},"showlegend":false,"textinfo":"none","values":{"dtype":"i2","bdata":"OA+1BkIJ4maKCWwR"},"type":"pie","domain":{"x":[0.35,0.6499999999999999],"y":[0.9428571428571428,1.0]}},{"hole":0.4,"labels":["BATTERY - SIMPLE ASSAULT","BURGLARY","BURGLARY FROM VEHICLE","Overig","THEFT OF IDENTITY","VEHICLE - STOLEN"],"marker":{"colors":["rgb(141,211,199)","rgb(255,255,179)","rgb(190,186,218)","rgb(251,128,114)","rgb(128,177,211)","rgb(253,180,98)"]},"showlegend":false,"textinfo":"none","values":{"dtype":"i2","bdata":"KRBoBygH1n5\u002fDdkU"},"type":"pie","domain":{"x":[0.7,1.0],"y":[0.9428571428571428,1.0]}},{"hole":0.4,"labels":["BATTERY - SIMPLE ASSAULT","BURGLARY","BURGLARY FROM VEHICLE","Overig","THEFT OF IDENTITY","VEHICLE - STOLEN"],"marker":{"colors":["rgb(141,211,199)","rgb(255,255,179)","rgb(190,186,218)","rgb(251,128,114)","rgb(128,177,211)","rgb(253,180,98)"]},"showlegend":false,"textinfo":"none","values":{"dtype":"i2","bdata":"hAslBqcEPk55B\u002fkT"},"type":"pie","domain":{"x":[0.0,0.3],"y":[0.7857142857142856,0.8428571428571427]}},{"hole":0.4,"labels":["BATTERY - SIMPLE ASSAULT","BURGLARY","BURGLARY FROM VEHICLE","Overig","THEFT OF IDENTITY","VEHICLE - STOLEN"],"marker":{"colors":["rgb(141,211,199)","rgb(255,255,179)","rgb(190,186,218)","rgb(251,128,114)","rgb(128,177,211)","rgb(253,180,98)"]},"showlegend":false,"textinfo":"none","values":{"dtype":"i2","bdata":"RgtICL8FM1nfBpYT"},"type":"pie","domain":{"x":[0.35,0.6499999999999999],"y":[0.7857142857142856,0.8428571428571427]}},{"hole":0.4,"labels":["BATTERY - SIMPLE ASSAULT","BURGLARY","BURGLARY FROM VEHICLE","Overig","THEFT OF IDENTITY","VEHICLE - STOLEN"],"marker":{"colors":["rgb(141,211,199)","rgb(255,255,179)","rgb(190,186,218)","rgb(251,128,114)","rgb(128,177,211)","rgb(253,180,98)"]},"showlegend":false,"textinfo":"none","values":{"dtype":"i2","bdata":"XRCRCXEONXZFCewM"},"type":"pie","domain":{"x":[0.7,1.0],"y":[0.7857142857142856,0.8428571428571427]}},{"hole":0.4,"labels":["BATTERY - SIMPLE ASSAULT","BURGLARY","BURGLARY FROM VEHICLE","Overig","THEFT OF IDENTITY","VEHICLE - STOLEN"],"marker":{"colors":["rgb(141,211,199)","rgb(255,255,179)","rgb(190,186,218)","rgb(251,128,114)","rgb(128,177,211)","rgb(253,180,98)"]},"showlegend":false,"textinfo":"none","values":{"dtype":"i2","bdata":"lwt1DQcLPmkvCU0N"},"type":"pie","domain":{"x":[0.0,0.3],"y":[0.6285714285714286,0.6857142857142857]}},{"hole":0.4,"labels":["BATTERY - SIMPLE ASSAULT","BURGLARY","BURGLARY FROM VEHICLE","Overig","THEFT OF IDENTITY","VEHICLE - STOLEN"],"marker":{"colors":["rgb(141,211,199)","rgb(255,255,179)","rgb(190,186,218)","rgb(251,128,114)","rgb(128,177,211)","rgb(253,180,98)"]},"showlegend":false,"textinfo":"none","values ...

# %% [markdown]
# Er valt te zien dat de verdelingen verschillen per gebied: 15/21 hebben als meest frequente misdaad autodiefstal, Central heeft vooral auto inbraak, en de andere gebieden hebben gelijkere verdelingen.

# %% [markdown]
# # Literatuurlijst
# [1] World Population Review, “Los Angeles, California Population 2026,” *World Population Review*, Jun. 16, 2026. https://worldpopulationreview.com/us-cities/california/los-angeles \
# [2] World Population Review, “New York, New York population 2026,” *World Population Review*, Jun. 16, 2026. https://worldpopulationreview.com/us-cities/new-york/new-york
